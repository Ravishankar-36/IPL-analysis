# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\RaviShankar R\.spyder-py3\Analytics\IPL\deliveries.csv')

# %%
df1=df.groupby(['batsman','bowler']).sum()
df2=df.groupby(['batsman','bowler']).count()

# %%
df1.to_csv('iplscore.csv')
df2.to_csv('iplballcount.csv')

# %%
dfipl1=pd.read_csv(r'C:\Users\RaviShankar R\.spyder-py3\Analytics\IPL\iplscore.csv')
dfipl2=pd.read_csv(r'C:\Users\RaviShankar R\.spyder-py3\Analytics\IPL\iplballcount.csv')

# %%
dfipl1[['batsman','bowler','batsman_runs',]]
# Out:
#               batsman           bowler  batsman_runs
# 0      A Ashish Reddy          A Nehra      0.777778
# 1      A Ashish Reddy         AB Dinda      1.285714
# 2      A Ashish Reddy       AD Mathews      2.083333
# 3      A Ashish Reddy       AD Russell      1.333333
# 4      A Ashish Reddy    Anureet Singh      1.000000
# ...               ...              ...           ...
# 19816          Z Khan        SR Watson      0.600000
# 19817          Z Khan  Shakib Al Hasan      1.000000
# 19818          Z Khan    Sohail Tanvir      0.600000
# 19819          Z Khan        VRV Singh      0.000000
# 19820          Z Khan        YK Pathan      0.500000
#
# [19821 rows x 3 columns]

# %%
MI=['R Sharma','S Rutherford','SA Yadav','CA Lynn','SS Tiwary','DS Kulkarni','JJ Bumrah','SL Malinga','MJ McClenaghan','RD Chahar',
   'TA Boult','HH Pandya','J Yadav','AP Tare','NM Coulter-Nile','Ishan Kishan','Q de Kock','KH Pandya','KA Pollard']

MI_data_missing=['Anmolpreet singh','Mohsin khan','Balwant rai singh','Digvijay Deshmukh','Ankul Roy']

# %%
CSK=['MS Dhoni','RA Jadeja','M Vijay','KM Jadhav','KV Sharma','PP Chawla','AT Rayudu','SK Raina','Imran Tahir','DL Chahar',
    'F du Plessis','SN Thakur','M Santner','DJ Bravo','S Curran','SR Watson','Harbhajan Singh']
CSK_data_missing=['Narayan jagadeesan','Ruturaj gaikwad','KM Asif','Josh hazlewood','Lungi Ngidi','Monu kumar','Sai kishore']

# %%
dfipl2
# Out:
#               batsman           bowler  match_id  inning  batting_team  \
# 0      A Ashish Reddy          A Nehra         9       9             9
# 1      A Ashish Reddy         AB Dinda         7       7             7
# 2      A Ashish Reddy       AD Mathews        12      12            12
# 3      A Ashish Reddy       AD Russell         3       3             3
# 4      A Ashish Reddy    Anureet Singh         2       2             2
# ...               ...              ...       ...     ...           ...
# 19816          Z Khan        SR Watson         5       5             5
# 19817          Z Khan  Shakib Al Hasan         3       3             3
# 19818          Z Khan    Sohail Tanvir         5       5             5
# 19819          Z Khan        VRV Singh         3       3             3
# 19820          Z Khan        YK Pathan         2       2             2
#
#        bowling_team  over  ball  non_striker  is_super_over  ...  bye_runs  \
# 0                 9     9     9            9              9  ...         9
# 1                 7     7     7            7              7  ...         7
# 2                12    12    12           12             12  ...        12
# 3                 3     3     3            3              3  ...         3
# 4                 2     2     2            2              2  ...         2
# ...             ...   ...   ...          ...            ...  ...       ...
# 19816             5     5     5            5              5  ...         5
# 19817             3     3     3            3              3  ...         3
# 19818             5     5     5            5              5  ...         5
# 19819             3     3     3            3              3  ...         3
# 19820             2     2     2            2              2  ...         2
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 0                9            9             9             9           9
# 1                7            7             7             7           7
# 2               12           12            12            12          12
# 3                3            3             3             3           3
# 4                2            2             2             2           2
# ...            ...          ...           ...           ...         ...
# 19816            5            5             5             5           5
# 19817            3            3             3             3           3
# 19818            5            5             5             5           5
# 19819            3            3             3             3           3
# 19820            2            2             2             2           2
#
#        total_runs  player_dismissed  dismissal_kind  fielder
# 0               9                 1               1        1
# 1               7                 0               0        0
# 2              12                 0               0        0
# 3               3                 1               1        1
# 4               2                 0               0        0
# ...           ...               ...             ...      ...
# 19816           5                 0               0        0
# 19817           3                 0               0        0
# 19818           5                 0               0        0
# 19819           3                 0               0        0
# 19820           2                 0               0        0
#
# [19821 rows x 21 columns]

# %%
cons_df=dfipl1[['batsman','bowler','batsman_runs']]

# %%
cons_df['ball_count']=dfipl2['batsman_runs']
# Out:
# C:\Users\RaviShankar R\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cons_df.columns=['batsman','bowler','avgrunsperball','totalballsfaced']

# %%
cons_df['combi']=cons_df['batsman']+cons_df['bowler']
# Out:
# C:\Users\RaviShankar R\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cons_df
# Out:
#               batsman           bowler  avgrunsperball  totalballsfaced  \
# 0      A Ashish Reddy          A Nehra        0.777778                9
# 1      A Ashish Reddy         AB Dinda        1.285714                7
# 2      A Ashish Reddy       AD Mathews        2.083333               12
# 3      A Ashish Reddy       AD Russell        1.333333                3
# 4      A Ashish Reddy    Anureet Singh        1.000000                2
# ...               ...              ...             ...              ...
# 19816          Z Khan        SR Watson        0.600000                5
# 19817          Z Khan  Shakib Al Hasan        1.000000                3
# 19818          Z Khan    Sohail Tanvir        0.600000                5
# 19819          Z Khan        VRV Singh        0.000000                3
# 19820          Z Khan        YK Pathan        0.500000                2
#
#                              combi
# 0            A Ashish ReddyA Nehra
# 1           A Ashish ReddyAB Dinda
# 2         A Ashish ReddyAD Mathews
# 3         A Ashish ReddyAD Russell
# 4      A Ashish ReddyAnureet Singh
# ...                            ...
# 19816              Z KhanSR Watson
# 19817        Z KhanShakib Al Hasan
# 19818          Z KhanSohail Tanvir
# 19819              Z KhanVRV Singh
# 19820              Z KhanYK Pathan
#
# [19821 rows x 5 columns]

# %%
from itertools import product

a=list(product(MI, CSK))
b=list(product(CSK, MI))

# %%
MI_CSK_combi=pd.DataFrame(a)
MI_CSK_combi['team']='MI'
CSK_MI_combi=pd.DataFrame(b)
CSK_MI_combi['team']='CSK'
frame=[CSK_MI_combi,MI_CSK_combi]
comb=pd.concat(frame)

# %%
comb.columns=['p1','p2','p1_team']
comb['playcomb']=MI_CSK_comb['p1']+MI_CSK_comb['p2']

# %%
players_combi=comb['playcomb'].to_list()

# %%
final=cons_df[cons_df['combi'].isin(players_combi)]

# %%
players=final['batsman'].to_list()
teamtag=[]
for a in players:
    if a in MI:
        teamtag.append('MI')
    else:
        teamtag.append('CSK')

final['team']=teamtag

# %%
final
# Out:
#          batsman       bowler  avgrunsperball  totalballsfaced  \
# 1654     AP Tare    DL Chahar        0.000000                1
# 1658     AP Tare  Imran Tahir        1.333333                3
# 1685     AP Tare    SR Watson        2.111111                9
# 1966   AT Rayudu  DS Kulkarni        1.454545               11
# 1972   AT Rayudu    HH Pandya        1.291667               24
# ...          ...          ...             ...              ...
# 17376  SS Tiwary    RA Jadeja        1.100000               10
# 17391  SS Tiwary     SK Raina        1.137931               29
# 17396  SS Tiwary    SR Watson        0.764706               17
# 18041   TA Boult     DJ Bravo        1.000000                1
# 18044   TA Boult    RA Jadeja        2.000000                3
#
#                       combi team
# 1654       AP TareDL Chahar   MI
# 1658     AP TareImran Tahir   MI
# 1685       AP TareSR Watson   MI
# 1966   AT RayuduDS Kulkarni  CSK
# 1972     AT RayuduHH Pandya  CSK
# ...                     ...  ...
# 17376    SS TiwaryRA Jadeja   MI
# 17391     SS TiwarySK Raina   MI
# 17396    SS TiwarySR Watson   MI
# 18041      TA BoultDJ Bravo   MI
# 18044     TA BoultRA Jadeja   MI
#
# [228 rows x 6 columns]

# %%
import numpy as np
weighted_score=final.groupby(["batsman","team"]).apply(lambda x: np.average(x['avgrunsperball'], weights=x['totalballsfaced']))

# %%
ws=pd.DataFrame(weighted_score)

# %%
ws.reset_index()
# Out:
#             batsman team         0
# 0           AP Tare   MI  1.769231
# 1         AT Rayudu  CSK  1.215827
# 2           CA Lynn   MI  1.412500
# 3          DJ Bravo  CSK  1.674603
# 4         DL Chahar  CSK  0.750000
# 5       DS Kulkarni   MI  1.636364
# 6      F du Plessis  CSK  1.111842
# 7         HH Pandya   MI  1.559633
# 8   Harbhajan Singh  CSK  1.153846
# 9       Imran Tahir  CSK  0.750000
# 10     Ishan Kishan   MI  1.201754
# 11          J Yadav   MI  0.500000
# 12        JJ Bumrah   MI  1.000000
# 13       KA Pollard   MI  1.658537
# 14        KH Pandya   MI  1.471264
# 15        KM Jadhav  CSK  1.025000
# 16        KV Sharma  CSK  0.714286
# 17        M Santner  CSK  1.294118
# 18          M Vijay  CSK  1.004762
# 19   MJ McClenaghan   MI  1.272727
# 20         MS Dhoni  CSK  1.333333
# 21  NM Coulter-Nile   MI  0.375000
# 22        PP Chawla  CSK  0.610169
# 23        Q de Kock   MI  1.208861
# 24         R Sharma   MI  0.900000
# 25        RA Jadeja  CSK  1.226562
# 26        RD Chahar   MI  0.333333
# 27         S Curran  CSK  2.666667
# 28     S Rutherford   MI  1.000000
# 29         SA Yadav   MI  1.166667
# 30         SK Raina  CSK  1.303406
# 31       SL Malinga   MI  0.578947
# 32        SN Thakur  CSK  1.900000
# 33        SR Watson  CSK  1.235088
# 34        SS Tiwary   MI  1.106870
# 35         TA Boult   MI  1.750000

# %%
ws.to_csv('weighted_score.csv')

# %%
wsf=pd.read_csv(r'C:\Users\RaviShankar R\.spyder-py3\Analytics\IPL\weighted_score.csv')

# %%
wsf.columns=['batsman', 'team','weightedruns_perball']

# %%
MIG=wsf['team']=='MI'
CSKG=wsf['team']=='CSK'

# %%
wsf[MIG].sort_values('weightedruns_perball',ascending=False)[0:10]['weightedruns_perball'].sum()
# Out:
# 14.940870804485144

# %%
import matplotlib.pyplot as plt
wsf2=wsf[MIG].sort_values('weightedruns_perball',ascending=False)[0:10]
plt.barh(wsf2['batsman'],wsf2['weightedruns_perball'])
# Out:
# <BarContainer object of 10 artists>

# %%
wsf[CSKG].sort_values('weightedruns_perball',ascending=False)[0:10]['weightedruns_perball'].sum()
# Out:
# 15.00345010569131

# %%
wsf3=wsf[CSKG].sort_values('weightedruns_perball',ascending=False)[0:10]
plt.barh(wsf3['batsman'],wsf3['weightedruns_perball'])
# Out:
# <BarContainer object of 10 artists>
